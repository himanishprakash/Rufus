# %%
import nest_asyncio
nest_asyncio.apply()

import asyncio
import json
import re
from urllib.parse import urljoin
import time
import os
from datetime import datetime
import logging
from typing import Dict, List, Set, Any
from openai import OpenAI
from playwright.async_api import async_playwright

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('semantic_crawler.log'),
        logging.StreamHandler()
    ]
)

class SemanticWebCrawler:
    def __init__(self, api_key: str):
        """
        Initialize the semantic web crawler.
        
        Args:
            api_key (str): OpenAI API key for semantic analysis
        """
        self.client = OpenAI(api_key=api_key)
        self.visited_urls: Set[str] = set()
        self.page_relevance: Dict[str, bool] = {}
        self.page_data: Dict[str, Dict[str, Any]] = {}
        self.depth_data: Dict[int, List[str]] = {}
        self.keywords: List[str] = []

    async def get_semantic_keywords(self, instruction: str) -> List[str]:
        """
        Generate semantically related keywords for the search instruction.
        """
        prompt = f"""Generate semantically related keywords and phrases for this instruction:
        
        Instruction: "{instruction}"
        
        Consider:
        1. Direct synonyms and related terms
        2. Industry-specific terminology
        3. Common abbreviations
        4. Related concepts and topics
        5. Contextual variations
        
        Return ONLY a comma-separated list of keywords, no explanations."""

        try:
            response = self.client.chat.completions.create(
                model="o1-mini",
                messages=[
                    {"role": "system", "content": "You are a semantic analysis expert. Return only a comma-separated list of keywords."},
                    {"role": "user", "content": prompt}
                ],
                temperature=0.3
            )
            
            keywords = [kw.strip() for kw in response.choices[0].message.content.split(',')]
            logging.info(f"Generated keywords: {keywords}")
            return keywords
            
        except Exception as e:
            logging.error(f"Error generating keywords: {str(e)}")
            return []

    def is_content_relevant(self, content: str, instruction: str, keywords: List[str]) -> bool:
        """
        Determine if page content is relevant using semantic analysis.
        """
        prompt = f"""Analyze if this content is relevant to the instruction and keywords.

        Instruction: "{instruction}"
        Keywords: {', '.join(keywords)}
        
        Content (excerpt):
        \"\"\"
        {content[:2000]}
        \"\"\"
        
        Consider:
        1. Direct keyword matches
        2. Semantic relationship to instruction
        3. Context and meaning
        4. Content quality and depth
        5. Information value
        
        Answer ONLY with TRUE or FALSE."""

        try:
            response = self.client.chat.completions.create(
                model="gpt-4o",
                messages=[
                    {"role": "system", "content": "You are a content relevance analyst. Respond only with TRUE or FALSE."},
                    {"role": "user", "content": prompt}
                ],
                temperature=0.3
            )
            
            is_relevant = response.choices[0].message.content.strip().upper() == "TRUE"
            logging.info(f"Content relevance: {is_relevant}")
            return is_relevant
            
        except Exception as e:
            logging.error(f"Error checking content relevance: {str(e)}")
            return False

    async def should_follow_link(self, link_text: str, href: str, 
                               instruction: str, keywords: List[str], 
                               surrounding_text: str = "") -> bool:
        """
        Determine if a link should be followed based on semantic analysis.
        """
        prompt = f"""Should we follow this link based on the instruction and context?
        
        Instruction: "{instruction}"
        Keywords: {', '.join(keywords)}
        
        Link Analysis:
        - Link Text: "{link_text}"
        - URL: {href}
        - Surrounding Context: "{surrounding_text}"
        
        Consider:
        1. Relevance to instruction
        2. Keyword matches
        3. URL structure/path
        4. Link context
        5. Potential information value
        
        Answer ONLY with TRUE or FALSE."""

        try:
            response = self.client.chat.completions.create(
                model="gpt-4",
                messages=[
                    {"role": "system", "content": "You are a link relevance analyst. Respond only with TRUE or FALSE."},
                    {"role": "user", "content": prompt}
                ],
                temperature=0.3
            )
            
            should_follow = response.choices[0].message.content.strip().upper() == "TRUE"
            logging.info(f"Should follow {href}: {should_follow}")
            return should_follow
            
        except Exception as e:
            logging.error(f"Error checking link relevance: {str(e)}")
            return False

    async def analyze_page_links(self, page, current_url: str, base_url: str, 
                               instruction: str) -> Dict[str, bool]:
        """
        Analyze all links on the current page for relevance.
        """
        link_relevance = {}
        try:
            links = await page.query_selector_all('a[href]')
            for link in links:
                href = await link.get_attribute('href')
                if href:
                    absolute_url = urljoin(current_url, href)
                    if absolute_url.startswith(base_url) and absolute_url not in self.visited_urls:
                        link_text = await link.inner_text()
                        parent = await link.evaluate('element => element.parentElement.textContent')
                        surrounding_text = parent[:200] if parent else ""
                        
                        is_relevant = await self.should_follow_link(
                            link_text, absolute_url, instruction, 
                            self.keywords, surrounding_text
                        )
                        link_relevance[absolute_url] = is_relevant
            
            return link_relevance
            
        except Exception as e:
            logging.error(f"Error in link analysis: {str(e)}")
            return link_relevance

    async def crawl_page(self, page, current_url: str, base_url: str, instruction: str, 
                        depth: int = 0, max_depth: int = 2):
        """
        Crawl a page and analyze its content and links.
        """
        if depth > max_depth or current_url in self.visited_urls:
            return
            
        self.visited_urls.add(current_url)
        
        if depth not in self.depth_data:
            self.depth_data[depth] = []
        
        try:
            # Generate keywords if not already done
            if not self.keywords:
                self.keywords = await self.get_semantic_keywords(instruction)
            
            await page.goto(current_url)
            logging.info(f"Crawling depth {depth}: {current_url}")
            
            await page.wait_for_load_state('networkidle')
            await asyncio.sleep(1)
            
            # Get and analyze content
            content = await page.inner_text('body')
            is_relevant = self.is_content_relevant(content, instruction, self.keywords)
            self.page_relevance[current_url] = is_relevant
            
            # Store relevant page data
            if is_relevant:
                self.page_data[current_url] = {
                    'url': current_url,
                    'depth': depth,
                    'content': content,
                    'crawl_time': datetime.now().isoformat(),
                    'title': await page.title(),
                    'matched_keywords': self.keywords
                }
                self.depth_data[depth].append(current_url)
            
            # Analyze and follow links if not at max depth
            if depth < max_depth:
                link_relevance = await self.analyze_page_links(page, current_url, base_url, instruction)
                
                for url, relevant in link_relevance.items():
                    if relevant and url not in self.visited_urls:
                        await self.crawl_page(
                            page, url, base_url, instruction, 
                            depth + 1, max_depth
                        )
                        
        except Exception as e:
            logging.error(f"Error crawling {current_url}: {str(e)}")

    def save_results(self, base_url: str, instruction: str):
        """
        Save crawl results to JSON file.
        """
        timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
        filename = f'semantic_results_{timestamp}.json'
        
        results = {
            'metadata': {
                'base_url': base_url,
                'instruction': instruction,
                'crawl_time': datetime.now().isoformat(),
                'total_pages': len(self.visited_urls),
                'relevant_pages': sum(1 for v in self.page_relevance.values() if v),
                'keywords_used': self.keywords
            },
            'relevance_map': self.page_relevance,
            'depth_analysis': {
                str(depth): {
                    'urls': urls,
                    'count': len(urls)
                } for depth, urls in self.depth_data.items()
            },
            'page_data': self.page_data
        }
        
        with open(filename, 'w', encoding='utf-8') as f:
            json.dump(results, f, ensure_ascii=False, indent=2)
        
        logging.info(f"Results saved to {filename}")
        return filename

    async def crawl(self, base_url: str, instruction: str, max_depth: int = 2):
        """
        Main crawling function.
        """
        if not base_url.startswith(('http://', 'https://')):
            base_url = 'https://' + base_url
        if not base_url.endswith('/'):
            base_url += '/'
            
        async with async_playwright() as p:
            browser = await p.chromium.launch(headless=True)
            page = await browser.new_page()
            
            try:
                await self.crawl_page(page, base_url, base_url, instruction, max_depth=max_depth)
                filename = self.save_results(base_url, instruction)
                logging.info(f"Crawl completed successfully. Results saved to {filename}")
                
            except Exception as e:
                logging.error(f"Crawl failed: {str(e)}")
            finally:
                await browser.close()

async def main():
    """
    Main function to run the crawler.
    """
    print("Semantic Web Crawler")
    print("-" * 50)
    
    c
    base_url = input("Enter the base URL to crawl: ").strip()
    instruction = input("Enter your search instruction: ").strip()
    max_depth = int(input("Enter maximum crawl depth (default 2): ") or "2")
    
    print("\nStarting crawl...")
    crawler = SemanticWebCrawler(api_key)
    await crawler.crawl(base_url, instruction, max_depth)
    print("Crawl completed!")

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# Semantic Web Crawler
# --------------------------------------------------
#
# Starting crawl...
# 2024-10-22 14:45:38,085 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 404 Not Found"
# 2024-10-22 14:45:38,090 - ERROR - Error generating keywords: Error code: 404 - {'error': {'message': 'The model `o1-mini` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# 2024-10-22 14:45:39,264 - INFO - Crawling depth 0: https://www.sf.gov/
# 2024-10-22 14:45:41,736 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:41,745 - INFO - Content relevance: False
# 2024-10-22 14:45:42,379 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:42,382 - INFO - Should follow https://www.sf.gov/#main-content: False
# 2024-10-22 14:45:43,065 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:43,070 - INFO - Should follow https://www.sf.gov/es: False
# 2024-10-22 14:45:43,785 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:43,787 - INFO - Should follow https://www.sf.gov/zh-hant: False
# 2024-10-22 14:45:44,497 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:44,499 - INFO - Should follow https://www.sf.gov/fil: False
# 2024-10-22 14:45:45,045 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:45,048 - INFO - Should follow https://www.sf.gov/services: False
# 2024-10-22 14:45:45,651 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:45,654 - INFO - Should follow https://www.sf.gov/departments: True
# 2024-10-22 14:45:46,208 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:46,210 - INFO - Should follow https://www.sf.gov/departments/department-elections: False
# 2024-10-22 14:45:47,129 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:47,134 - INFO - Should follow https://www.sf.gov/topics/activities: False
# 2024-10-22 14:45:47,731 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:47,737 - INFO - Should follow https://www.sf.gov/topics/building: False
# 2024-10-22 14:45:48,361 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:48,364 - INFO - Should follow https://www.sf.gov/topics/business: True
# 2024-10-22 14:45:49,035 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:49,037 - INFO - Should follow https://www.sf.gov/topics/disability: False
# 2024-10-22 14:45:49,846 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:49,849 - INFO - Should follow https://www.sf.gov/topics/food: False
# 2024-10-22 14:45:50,443 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:50,445 - INFO - Should follow https://www.sf.gov/topics/government: False
# 2024-10-22 14:45:51,052 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:51,054 - INFO - Should follow https://www.sf.gov/topics/health: False
# 2024-10-22 14:45:51,699 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:51,701 - INFO - Should follow https://www.sf.gov/topics/homelessness: False
# 2024-10-22 14:45:52,500 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:52,574 - INFO - Should follow https://www.sf.gov/topics/housing: False
# 2024-10-22 14:45:53,290 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:53,294 - INFO - Should follow https://www.sf.gov/topics/immigrants: False
# 2024-10-22 14:45:53,957 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:53,959 - INFO - Should follow https://www.sf.gov/topics/jobs: True
# 2024-10-22 14:45:54,558 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:54,560 - INFO - Should follow https://www.sf.gov/topics/problems-and-complaints: False
# 2024-10-22 14:45:55,266 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:55,269 - INFO - Should follow https://www.sf.gov/topics/safety: False
# 2024-10-22 14:45:55,972 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:55,975 - INFO - Should follow https://www.sf.gov/topics/transportation: False
# 2024-10-22 14:45:56,577 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:56,580 - INFO - Should follow https://www.sf.gov/news/mayor-london-breed-celebrates-acquisition-new-senior-center-soma-neighborhood: False
# 2024-10-22 14:45:57,284 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:57,287 - INFO - Should follow https://www.sf.gov/news/mayor-london-breed-celebrates-grand-opening-bayfront-park-mission-bay: False
# 2024-10-22 14:45:58,503 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:58,507 - INFO - Should follow https://www.sf.gov/news/department-elections-reminds-voters-return-their-completed-ballots: False
# 2024-10-22 14:45:59,293 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:59,300 - INFO - Should follow https://www.sf.gov/news/mayor-london-breed-and-bayview-hunters-point-community-celebrate-opening-india-basin: False
# 2024-10-22 14:45:59,882 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:45:59,885 - INFO - Should follow https://www.sf.gov/news/all: False
# 2024-10-22 14:46:00,558 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:00,560 - INFO - Should follow https://www.sf.gov/profile/london-breed: False
# 2024-10-22 14:46:01,148 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:01,151 - INFO - Should follow https://www.sf.gov/profile/aaron-peskin: False
# 2024-10-22 14:46:01,744 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:01,753 - INFO - Should follow https://www.sf.gov/profile/connie-chan: False
# 2024-10-22 14:46:02,393 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:02,396 - INFO - Should follow https://www.sf.gov/profile/catherine-stefani: False
# 2024-10-22 14:46:02,939 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:02,943 - INFO - Should follow https://www.sf.gov/profile/joel-engardio: False
# 2024-10-22 14:46:03,540 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:03,543 - INFO - Should follow https://www.sf.gov/profile/dean-preston: False
# 2024-10-22 14:46:04,194 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:04,197 - INFO - Should follow https://www.sf.gov/profile/matt-dorsey: False
# 2024-10-22 14:46:04,768 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:04,771 - INFO - Should follow https://www.sf.gov/profile/myrna-melgar: False
# 2024-10-22 14:46:05,468 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:05,471 - INFO - Should follow https://www.sf.gov/profile/rafael-mandelman: False
# 2024-10-22 14:46:06,053 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:06,058 - INFO - Should follow https://www.sf.gov/profile/hillary-ronen: False
# 2024-10-22 14:46:06,820 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:06,823 - INFO - Should follow https://www.sf.gov/profile/shamann-walton: False
# 2024-10-22 14:46:07,423 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:07,426 - INFO - Should follow https://www.sf.gov/profile/ahsha-safai: False
# 2024-10-22 14:46:08,050 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:08,052 - INFO - Should follow https://www.sf.gov/node/195: False
# 2024-10-22 14:46:08,681 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:08,683 - INFO - Should follow https://www.sf.gov/profile/brooke-jenkins: False
# 2024-10-22 14:46:09,347 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:09,350 - INFO - Should follow https://www.sf.gov/profile/paul-miyamoto: False
# 2024-10-22 14:46:10,290 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:10,292 - INFO - Should follow https://www.sf.gov/profile/jose-cisneros: False
# 2024-10-22 14:46:10,863 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:10,866 - INFO - Should follow https://www.sf.gov/profile/joaquin-torres: False
# 2024-10-22 14:46:11,532 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:11,536 - INFO - Should follow https://www.sf.gov/profile/david-chiu: False
# 2024-10-22 14:46:12,199 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:12,201 - INFO - Should follow https://www.sf.gov/contact-sfgov: False
# 2024-10-22 14:46:12,897 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:12,900 - INFO - Should follow https://www.sf.gov/information/about-sfgov: True
# 2024-10-22 14:46:13,489 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:13,492 - INFO - Should follow https://www.sf.gov/information/disclaimer-sfgov: False
# 2024-10-22 14:46:14,055 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:14,056 - INFO - Should follow https://www.sf.gov/information/privacy-policy-sfgov: False
# 2024-10-22 14:46:14,300 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 404 Not Found"
# 2024-10-22 14:46:14,303 - ERROR - Error generating keywords: Error code: 404 - {'error': {'message': 'The model `o1-mini` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# 2024-10-22 14:46:15,014 - INFO - Crawling depth 1: https://www.sf.gov/departments
# 2024-10-22 14:46:17,520 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:17,524 - INFO - Content relevance: False
# 2024-10-22 14:46:18,272 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:18,274 - INFO - Should follow https://www.sf.gov/departments#main-content: False
# 2024-10-22 14:46:19,005 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:19,007 - INFO - Should follow https://www.sf.gov/es/departments: False
# 2024-10-22 14:46:19,744 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:19,748 - INFO - Should follow https://www.sf.gov/zh-hant/departments: False
# 2024-10-22 14:46:20,387 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:20,389 - INFO - Should follow https://www.sf.gov/fil/departments: False
# 2024-10-22 14:46:20,955 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:20,958 - INFO - Should follow https://www.sf.gov/services: False
# 2024-10-22 14:46:21,581 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:21,583 - INFO - Should follow https://www.sf.gov/departments/311-customer-service-center: False
# 2024-10-22 14:46:22,205 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:22,208 - INFO - Should follow https://www.sf.gov/departments/adult-probation-department: False
# 2024-10-22 14:46:23,373 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:23,376 - INFO - Should follow https://www.sf.gov/departments/airport: False
# 2024-10-22 14:46:24,055 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:24,056 - INFO - Should follow https://www.sf.gov/departments/animal-care-and-control: False
# 2024-10-22 14:46:24,635 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:24,637 - INFO - Should follow https://www.sf.gov/departments/arts-commission: False
# 2024-10-22 14:46:25,267 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:25,270 - INFO - Should follow https://www.sf.gov/departments/asian-art-museum: False
# 2024-10-22 14:46:26,074 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:26,078 - INFO - Should follow https://www.sf.gov/departments/assessment-appeals-board: False
# 2024-10-22 14:46:26,661 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:26,664 - INFO - Should follow https://www.sf.gov/departments/assessor-recorder: False
# 2024-10-22 14:46:27,263 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:27,267 - INFO - Should follow https://www.sf.gov/departments/department-public-health/behavioral-health: False
# 2024-10-22 14:46:27,921 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:27,923 - INFO - Should follow https://www.sf.gov/departments/board-appeals: False
# 2024-10-22 14:46:28,534 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:28,537 - INFO - Should follow https://www.sf.gov/departments/board-supervisors: False
# 2024-10-22 14:46:29,570 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:29,572 - INFO - Should follow https://www.sf.gov/departments/california-academy-sciences: False
# 2024-10-22 14:46:30,173 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:30,176 - INFO - Should follow https://www.sf.gov/departments/child-care-health-program-cchp: False
# 2024-10-22 14:46:30,747 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:30,748 - INFO - Should follow https://www.sf.gov/departments/child-support-services: False
# 2024-10-22 14:46:31,332 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:31,336 - INFO - Should follow https://www.sf.gov/departments/children-and-families-commission: False
# 2024-10-22 14:46:32,182 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:32,184 - INFO - Should follow https://www.sf.gov/departments/children-youth-and-their-families: False
# 2024-10-22 14:46:32,839 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:32,841 - INFO - Should follow https://www.sf.gov/departments/city-administrator: False
# 2024-10-22 14:46:33,628 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:33,631 - INFO - Should follow https://www.sf.gov/departments/city-attorney: False
# 2024-10-22 14:46:34,285 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:34,288 - INFO - Should follow https://www.sf.gov/departments/civil-grand-jury: False
# 2024-10-22 14:46:35,091 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:35,093 - INFO - Should follow https://www.sf.gov/departments/civil-service-commission: True
# 2024-10-22 14:46:35,801 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:35,805 - INFO - Should follow https://www.sf.gov/departments/committee-information-technology: False
# 2024-10-22 14:46:36,385 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:36,388 - INFO - Should follow https://www.sf.gov/departments/contract-monitoring-division: False
# 2024-10-22 14:46:36,921 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:36,924 - INFO - Should follow https://www.sf.gov/departments/controllers-office: False
# 2024-10-22 14:46:37,850 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:37,853 - INFO - Should follow https://www.sf.gov/departments/convention-facilities-department: False
# 2024-10-22 14:46:38,577 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:38,580 - INFO - Should follow https://www.sf.gov/departments/city-administrator/datasf: True
# 2024-10-22 14:46:39,289 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:39,291 - INFO - Should follow https://www.sf.gov/departments/department-building-inspection: False
# 2024-10-22 14:46:39,890 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:39,892 - INFO - Should follow https://www.sf.gov/departments/human-services-agency/department-disability-and-aging-services: False
# 2024-10-22 14:46:40,801 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:40,804 - INFO - Should follow https://www.sf.gov/departments/department-elections: False
# 2024-10-22 14:46:41,716 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:41,720 - INFO - Should follow https://www.sf.gov/departments/department-emergency-management: False
# 2024-10-22 14:46:42,871 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:42,873 - INFO - Should follow https://www.sf.gov/departments/department-police-accountability: False
# 2024-10-22 14:46:43,482 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:43,486 - INFO - Should follow https://www.sf.gov/departments/department-public-health: False
# 2024-10-22 14:46:44,103 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:44,105 - INFO - Should follow https://www.sf.gov/departments/department-public-health-human-resources: False
# 2024-10-22 14:46:44,664 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:44,667 - INFO - Should follow https://www.sf.gov/departments/department-technology: True
# 2024-10-22 14:46:45,326 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:45,330 - INFO - Should follow https://www.sf.gov/departments/city-administrator/digital-services: True
# 2024-10-22 14:46:46,051 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:46,053 - INFO - Should follow https://www.sf.gov/departments/disaster-council: False
# 2024-10-22 14:46:46,618 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:46,621 - INFO - Should follow https://www.sf.gov/departments/department-public-health/disease-prevention-and-control: False
# 2024-10-22 14:46:47,184 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:47,187 - INFO - Should follow https://www.sf.gov/departments/district-attorney: False
# 2024-10-22 14:46:48,051 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:48,054 - INFO - Should follow https://www.sf.gov/departments/dph-office-compliance-and-privacy-affairs: False
# 2024-10-22 14:46:48,661 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:48,663 - INFO - Should follow https://www.sf.gov/departments/elections-commission: False
# 2024-10-22 14:46:49,421 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:49,424 - INFO - Should follow https://www.sf.gov/departments/department-emergency-management/emergency-medical-services-agency: False
# 2024-10-22 14:46:50,208 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:50,211 - INFO - Should follow https://www.sf.gov/departments/city-administrator/entertainment-commission: False
# 2024-10-22 14:46:50,868 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:50,872 - INFO - Should follow https://www.sf.gov/departments/environment-department: False
# 2024-10-22 14:46:51,498 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:51,500 - INFO - Should follow https://www.sf.gov/departments/department-public-health/environmental-health: False
# 2024-10-22 14:46:52,086 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:52,087 - INFO - Should follow https://www.sf.gov/departments/ethics-commission: False
# 2024-10-22 14:46:52,725 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:52,730 - INFO - Should follow https://www.sf.gov/departments/office-economic-and-workforce-development/film-sf: False
# 2024-10-22 14:46:53,322 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:53,323 - INFO - Should follow https://www.sf.gov/departments/fine-arts-museums: False
# 2024-10-22 14:46:53,931 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:53,935 - INFO - Should follow https://www.sf.gov/departments/fire-commission: False
# 2024-10-22 14:46:54,489 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:54,491 - INFO - Should follow https://www.sf.gov/departments/fire-department: False
# 2024-10-22 14:46:55,471 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:55,476 - INFO - Should follow https://www.sf.gov/departments/city-administrator/grants-arts: False
# 2024-10-22 14:46:56,113 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:56,117 - INFO - Should follow https://www.sf.gov/departments/historic-preservation-commission: False
# 2024-10-22 14:46:56,741 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:56,743 - INFO - Should follow https://www.sf.gov/departments/homelessness-and-supportive-housing: False
# 2024-10-22 14:46:57,265 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:57,268 - INFO - Should follow https://www.sf.gov/departments/human-resources: True
# 2024-10-22 14:46:57,968 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:57,969 - INFO - Should follow https://www.sf.gov/departments/human-rights-commission: False
# 2024-10-22 14:46:58,635 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:58,637 - INFO - Should follow https://www.sf.gov/departments/human-services-agency: True
# 2024-10-22 14:46:59,356 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:59,359 - INFO - Should follow https://www.sf.gov/departments/immigrant-services-and-resources: False
# 2024-10-22 14:46:59,945 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:46:59,949 - INFO - Should follow https://www.sf.gov/departments/jury-commissioner-jury-duty: False
# 2024-10-22 14:47:00,536 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:00,539 - INFO - Should follow https://www.sf.gov/departments/juvenile-justice-coordinating-council: False
# 2024-10-22 14:47:01,135 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:01,137 - INFO - Should follow https://www.sf.gov/departments/juvenile-probation-commission: False
# 2024-10-22 14:47:01,695 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:01,697 - INFO - Should follow https://www.sf.gov/departments/juvenile-probation-department: False
# 2024-10-22 14:47:02,307 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:02,310 - INFO - Should follow https://www.sf.gov/departments/department-public-health/laguna-honda-hospital-and-rehabilitation-center: False
# 2024-10-22 14:47:03,041 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:03,044 - INFO - Should follow https://www.sf.gov/departments/mayors-office-housing-and-community-development: False
# 2024-10-22 14:47:03,715 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:03,718 - INFO - Should follow https://www.sf.gov/departments/mayors-office-innovation: False
# 2024-10-22 14:47:04,321 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:04,324 - INFO - Should follow https://www.sf.gov/departments/mayors-office-disability: False
# 2024-10-22 14:47:04,987 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:04,990 - INFO - Should follow https://www.sf.gov/departments/municipal-transportation-agency: False
# 2024-10-22 14:47:05,746 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:05,749 - INFO - Should follow https://www.sf.gov/departments/office-cannabis: False
# 2024-10-22 14:47:06,423 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:06,426 - INFO - Should follow https://www.sf.gov/departments/city-administrator/office-civic-engagement-and-immigrant-affairs: False
# 2024-10-22 14:47:07,013 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:07,016 - INFO - Should follow https://www.sf.gov/departments/office-community-investment-infrastructure: False
# 2024-10-22 14:47:07,781 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:07,785 - INFO - Should follow https://www.sf.gov/departments/city-administrator/office-contract-administration: False
# 2024-10-22 14:47:08,363 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:08,366 - INFO - Should follow https://www.sf.gov/departments/office-economic-and-workforce-development: False
# 2024-10-22 14:47:08,980 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:08,985 - INFO - Should follow https://www.sf.gov/departments/office-financial-empowerment: False
# 2024-10-22 14:47:09,543 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:09,546 - INFO - Should follow https://www.sf.gov/departments/office-labor-standards-enforcement: True
# 2024-10-22 14:47:10,263 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:10,266 - INFO - Should follow https://www.sf.gov/departments/office-economic-and-workforce-development/office-small-business: False
# 2024-10-22 14:47:10,819 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:10,820 - INFO - Should follow https://www.sf.gov/departments/city-administrator/office-chief-medical-examiner: False
# 2024-10-22 14:47:11,391 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:11,393 - INFO - Should follow https://www.sf.gov/departments/city-administrator/office-county-clerk: False
# 2024-10-22 14:47:12,059 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:12,062 - INFO - Should follow https://www.sf.gov/departments/office-inspector-general: False
# 2024-10-22 14:47:13,832 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:13,836 - INFO - Should follow https://www.sf.gov/departments/office-mayor: False
# 2024-10-22 14:47:14,509 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:14,510 - INFO - Should follow https://www.sf.gov/departments/city-administrator/office-transgender-initiatives: False
# 2024-10-22 14:47:15,125 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:15,129 - INFO - Should follow https://www.sf.gov/departments/city-administrator/permit-center: False
# 2024-10-22 14:47:16,046 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:16,048 - INFO - Should follow https://www.sf.gov/departments/police-department: False
# 2024-10-22 14:47:16,676 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:16,679 - INFO - Should follow https://www.sf.gov/departments/port: False
# 2024-10-22 14:47:17,311 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:17,314 - INFO - Should follow https://www.sf.gov/departments/public-defender: False
# 2024-10-22 14:47:17,992 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:17,993 - INFO - Should follow https://www.sf.gov/departments/public-utilities-commission: False
# 2024-10-22 14:47:18,608 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:18,610 - INFO - Should follow https://www.sf.gov/departments/city-administrator/public-works: False
# 2024-10-22 14:47:19,226 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:19,228 - INFO - Should follow https://www.sf.gov/departments/real-estate-division: False
# 2024-10-22 14:47:20,181 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:20,188 - INFO - Should follow https://www.sf.gov/departments/recreation-and-park-department/recreation-park-commission: False
# 2024-10-22 14:47:20,863 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:20,867 - INFO - Should follow https://www.sf.gov/departments/recreation-and-park-department: False
# 2024-10-22 14:47:21,632 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:21,635 - INFO - Should follow https://www.sf.gov/departments/rent-board: False
# 2024-10-22 14:47:22,289 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:22,291 - INFO - Should follow https://www.sf.gov/departments/city-administrator/san-francisco-city-hall-events-office: False
# 2024-10-22 14:47:22,982 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:22,984 - INFO - Should follow https://www.sf.gov/departments/san-francisco-employees-retirement-system-sfers: False
# 2024-10-22 14:47:23,544 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:23,546 - INFO - Should follow https://www.sf.gov/departments/san-francisco-government-tv: False
# 2024-10-22 14:47:24,339 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:24,341 - INFO - Should follow https://www.sf.gov/departments/department-public-health/san-francisco-health-network: False
# 2024-10-22 14:47:24,976 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:24,978 - INFO - Should follow https://www.sf.gov/departments/san-francisco-health-service-system: False
# 2024-10-22 14:47:25,804 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:25,806 - INFO - Should follow https://www.sf.gov/departments/san-francisco-law-library: False
# 2024-10-22 14:47:26,422 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:26,424 - INFO - Should follow https://www.sf.gov/departments/human-resources/sf-city-jobs: True
# 2024-10-22 14:47:26,993 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:26,996 - INFO - Should follow https://www.sf.gov/departments/sf-library: False
# 2024-10-22 14:47:27,620 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:27,622 - INFO - Should follow https://www.sf.gov/departments/sf-planning: False
# 2024-10-22 14:47:28,434 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:28,437 - INFO - Should follow https://www.sf.gov/departments/sf-unified-school-district: False
# 2024-10-22 14:47:29,153 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:29,155 - INFO - Should follow https://www.sf.gov/departments/sheriffs-department-oversight-board: False
# 2024-10-22 14:47:29,826 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:29,829 - INFO - Should follow https://www.sf.gov/departments/sheriffs-office: False
# 2024-10-22 14:47:30,605 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:30,610 - INFO - Should follow https://www.sf.gov/departments/status-women: False
# 2024-10-22 14:47:31,310 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:31,312 - INFO - Should follow https://www.sf.gov/departments/superior-court: False
# 2024-10-22 14:47:31,915 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:31,919 - INFO - Should follow https://www.sf.gov/departments/food-security-task-force: False
# 2024-10-22 14:47:32,515 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:32,518 - INFO - Should follow https://www.sf.gov/departments/department-technology/office-cybersecurity: False
# 2024-10-22 14:47:33,252 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:33,256 - INFO - Should follow https://www.sf.gov/departments/city-administrator/treasure-island-development-authority: False
# 2024-10-22 14:47:33,885 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:33,887 - INFO - Should follow https://www.sf.gov/departments/treasurer-tax-collector: False
# 2024-10-22 14:47:34,420 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:34,423 - INFO - Should follow https://www.sf.gov/departments/war-memorial: False
# 2024-10-22 14:47:35,015 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:35,019 - INFO - Should follow https://www.sf.gov/contact-sfgov: False
# 2024-10-22 14:47:35,743 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:35,744 - INFO - Should follow https://www.sf.gov/information/about-sfgov: True
# 2024-10-22 14:47:36,424 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:36,428 - INFO - Should follow https://www.sf.gov/information/disclaimer-sfgov: False
# 2024-10-22 14:47:37,038 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:37,040 - INFO - Should follow https://www.sf.gov/information/privacy-policy-sfgov: True
# 2024-10-22 14:47:37,261 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 404 Not Found"
# 2024-10-22 14:47:37,264 - ERROR - Error generating keywords: Error code: 404 - {'error': {'message': 'The model `o1-mini` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# 2024-10-22 14:47:38,602 - INFO - Crawling depth 2: https://www.sf.gov/departments/civil-service-commission
# 2024-10-22 14:47:41,138 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:41,141 - INFO - Content relevance: False
# 2024-10-22 14:47:41,924 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:41,926 - INFO - Should follow https://www.sf.gov/departments/civil-service-commission#main-content: True
# 2024-10-22 14:47:42,514 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:42,518 - INFO - Should follow https://www.sf.gov/es/node/471: False
# 2024-10-22 14:47:43,183 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:43,186 - INFO - Should follow https://www.sf.gov/zh-hant/node/471: False
# 2024-10-22 14:47:43,815 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:43,820 - INFO - Should follow https://www.sf.gov/fil/node/471: False
# 2024-10-22 14:47:44,718 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:44,720 - INFO - Should follow https://www.sf.gov/services: False
# 2024-10-22 14:47:45,410 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:45,414 - INFO - Should follow https://www.sf.gov/reports/november-2023/civil-service-commission-2024-meeting-calendar: False
# 2024-10-22 14:47:46,024 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:46,026 - INFO - Should follow https://www.sf.gov/file/csc-memo-2024-02-posting-memo-proposed-amendments-rule-series-020-leaves-absence: False
# 2024-10-22 14:47:46,767 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:46,769 - INFO - Should follow https://www.sf.gov/meeting/october-21-2024/civil-service-commission-regular-meeting: False
# 2024-10-22 14:47:47,444 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:47,447 - INFO - Should follow https://www.sf.gov/meeting/october-7-2024/civil-service-commission-regular-meeting: False
# 2024-10-22 14:47:48,148 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:48,153 - INFO - Should follow https://www.sf.gov/meeting/september-16-2024/civil-service-commission-regular-meeting: False
# 2024-10-22 14:47:48,916 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:48,918 - INFO - Should follow https://www.sf.gov/departments/civil-service-commission/past-meetings: False
# 2024-10-22 14:47:49,674 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:49,677 - INFO - Should follow https://www.sf.gov/file-appeal-civil-service-commission: False
# 2024-10-22 14:47:50,274 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:50,277 - INFO - Should follow https://www.sf.gov/prepare-documents-civil-service-commission-appeal: False
# 2024-10-22 14:47:50,965 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:50,966 - INFO - Should follow https://www.sf.gov/ask-reschedule-civil-service-commission-hearing: False
# 2024-10-22 14:47:51,889 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:51,891 - INFO - Should follow https://www.sf.gov/step-by-step/prepare-staff-report-civil-service-commission: False
# 2024-10-22 14:47:52,504 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:52,510 - INFO - Should follow https://www.sf.gov/file-action-request-civil-service-commission-hearing: False
# 2024-10-22 14:47:53,289 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:53,291 - INFO - Should follow https://www.sf.gov/get-copy-report-civil-service-commission: False
# 2024-10-22 14:47:53,855 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:53,857 - INFO - Should follow https://www.sf.gov/request-civil-service-commission-inspection-and-audit: False
# 2024-10-22 14:47:54,527 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:54,532 - INFO - Should follow https://www.sf.gov/file-bargaining-unit-assignment-protest: False
# 2024-10-22 14:47:55,168 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:55,171 - INFO - Should follow https://www.sf.gov/management-supervisory-or-confidential-designation-complaint: False
# 2024-10-22 14:47:55,843 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:55,845 - INFO - Should follow https://www.sf.gov/filing-petitions-recognition-challenging-or-decertification-union: False
# 2024-10-22 14:47:56,416 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:56,418 - INFO - Should follow https://www.sf.gov/file-unfair-labor-practice-charge: False
# 2024-10-22 14:47:57,084 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:57,087 - INFO - Should follow https://www.sf.gov/respond-unfair-labor-practice-charge: False
# 2024-10-22 14:47:57,828 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:57,829 - INFO - Should follow https://www.sf.gov/file-action-request-mta-service-critical-staff-hearing: False
# 2024-10-22 14:47:58,543 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:58,545 - INFO - Should follow https://www.sf.gov/step-by-step/prepare-mta-service-critical-staff-report-csc: False
# 2024-10-22 14:47:59,146 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:59,149 - INFO - Should follow https://www.sf.gov/reports/december-2017/rule-114-appointments-civil-service-commission: False
# 2024-10-22 14:47:59,774 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:47:59,777 - INFO - Should follow https://www.sf.gov/reports/july-2000/rule-117-probationary-period-civil-service-commission: False
# 2024-10-22 14:48:00,056 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2024-10-22 14:48:00,058 - INFO - Retrying request to /chat/completions in 0.372000 seconds
# 2024-10-22 14:48:01,104 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:48:01,108 - INFO - Should follow https://www.sf.gov/reports/july-2000/rule-119-resignation-civil-service-commission: False
# 2024-10-22 14:48:01,386 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2024-10-22 14:48:01,387 - INFO - Retrying request to /chat/completions in 0.186000 seconds
# 2024-10-22 14:48:02,162 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:48:02,166 - INFO - Should follow https://www.sf.gov/reports/january-2007/rule-120-leaves-absence-civil-service-commission: False
# 2024-10-22 14:48:02,448 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2024-10-22 14:48:02,449 - INFO - Retrying request to /chat/completions in 0.336000 seconds
# 2024-10-22 14:48:03,800 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:48:03,804 - INFO - Should follow https://www.sf.gov/reports/december-2017/rule-122-employee-separation-procedures-civil-service-commission: True
# 2024-10-22 14:48:04,415 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:48:04,416 - INFO - Should follow https://www.sf.gov/reports/september-1995/policy-prohibiting-violence-workplace-civil-service-commission: True
# 2024-10-22 14:48:04,673 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2024-10-22 14:48:04,674 - INFO - Retrying request to /chat/completions in 0.480000 seconds
# 2024-10-22 14:48:05,709 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:48:05,710 - INFO - Should follow https://www.sf.gov/resource/2022/civil-service-commission-policies: True
# 2024-10-22 14:48:05,976 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2024-10-22 14:48:05,977 - INFO - Retrying request to /chat/completions in 0.300000 seconds
# 2024-10-22 14:48:06,942 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:48:06,944 - INFO - Should follow https://www.sf.gov/resource/2022/civil-service-advisers: True
# 2024-10-22 14:48:07,353 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2024-10-22 14:48:07,354 - INFO - Retrying request to /chat/completions in 0.462000 seconds
# 2024-10-22 14:48:08,374 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:48:08,376 - INFO - Should follow https://www.sf.gov/resource/2022/rules-apply-most-city-employees-civil-service-commission-vol-i: True
# 2024-10-22 14:48:08,626 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2024-10-22 14:48:08,626 - INFO - Retrying request to /chat/completions in 0.492000 seconds
# 2024-10-22 14:48:09,908 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ...
# 2024-10-22 14:58:43,252 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:43,255 - INFO - Should follow https://www.sf.gov/apply-be-mentor-project-pull: False
# 2024-10-22 14:58:43,861 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:43,864 - INFO - Should follow https://www.sf.gov/apply-be-team-leader-project-pull: False
# 2024-10-22 14:58:44,559 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:44,563 - INFO - Should follow https://www.sf.gov/ambassadorapply: False
# 2024-10-22 14:58:45,201 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:45,205 - INFO - Should follow https://www.sf.gov/apply-become-community-ambassador-trainee: False
# 2024-10-22 14:58:45,956 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:45,959 - INFO - Should follow https://www.sf.gov/news/topics/jobs: True
# 2024-10-22 14:58:46,577 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:46,579 - INFO - Should follow https://www.sf.gov/past-events/topics/jobs: False
# 2024-10-22 14:58:47,279 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:47,282 - INFO - Should follow https://www.sf.gov/contact-sfgov: False
# 2024-10-22 14:58:47,902 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:47,905 - INFO - Should follow https://www.sf.gov/information/disclaimer-sfgov: False
# 2024-10-22 14:58:48,266 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 404 Not Found"
# 2024-10-22 14:58:48,270 - ERROR - Error generating keywords: Error code: 404 - {'error': {'message': 'The model `o1-mini` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# 2024-10-22 14:58:48,312 - INFO - Crawling depth 2: https://www.sf.gov/topics/jobs#main-content
# 2024-10-22 14:58:49,910 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:49,915 - INFO - Content relevance: False
# 2024-10-22 14:58:50,468 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:50,470 - INFO - Should follow https://www.sf.gov/es/node/2048: False
# 2024-10-22 14:58:51,017 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:51,021 - INFO - Should follow https://www.sf.gov/zh-hant/node/2048: False
# 2024-10-22 14:58:51,749 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:51,751 - INFO - Should follow https://www.sf.gov/fil/node/2048: False
# 2024-10-22 14:58:52,372 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:52,374 - INFO - Should follow https://www.sf.gov/services: False
# 2024-10-22 14:58:53,590 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:53,594 - INFO - Should follow https://www.sf.gov/search-jobs: False
# 2024-10-22 14:58:54,281 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:54,284 - INFO - Should follow https://www.sf.gov/join-or-rejoin-workforce: True
# 2024-10-22 14:58:54,835 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:54,838 - INFO - Should follow https://www.sf.gov/apply-technologist-positions: False
# 2024-10-22 14:58:55,678 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:55,679 - INFO - Should follow https://www.sf.gov/apply-city-apprenticeships: False
# 2024-10-22 14:58:56,349 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:56,353 - INFO - Should follow https://www.sf.gov/learn-about-sf-fellowships: True
# 2024-10-22 14:58:57,079 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:57,083 - INFO - Should follow https://www.sf.gov/apply-internship-dpas-law-and-justice-reform-internship-program: False
# 2024-10-22 14:58:58,330 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:58,332 - INFO - Should follow https://www.sf.gov/apply-internship-project-pull: False
# 2024-10-22 14:58:59,018 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:59,021 - INFO - Should follow https://www.sf.gov/apply-internship-human-rights-commission: False
# 2024-10-22 14:58:59,566 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:58:59,568 - INFO - Should follow https://www.sf.gov/apply-be-mentor-project-pull: False
# 2024-10-22 14:59:00,266 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:00,271 - INFO - Should follow https://www.sf.gov/apply-be-team-leader-project-pull: False
# 2024-10-22 14:59:00,877 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:00,880 - INFO - Should follow https://www.sf.gov/ambassadorapply: False
# 2024-10-22 14:59:01,580 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:01,582 - INFO - Should follow https://www.sf.gov/apply-become-community-ambassador-trainee: False
# 2024-10-22 14:59:02,264 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:02,266 - INFO - Should follow https://www.sf.gov/news/topics/jobs: True
# 2024-10-22 14:59:02,835 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:02,840 - INFO - Should follow https://www.sf.gov/past-events/topics/jobs: False
# 2024-10-22 14:59:03,835 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:03,839 - INFO - Should follow https://www.sf.gov/contact-sfgov: False
# 2024-10-22 14:59:04,482 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:04,493 - INFO - Should follow https://www.sf.gov/information/disclaimer-sfgov: False
# 2024-10-22 14:59:04,740 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 404 Not Found"
# 2024-10-22 14:59:04,741 - ERROR - Error generating keywords: Error code: 404 - {'error': {'message': 'The model `o1-mini` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# 2024-10-22 14:59:05,796 - INFO - Crawling depth 3: https://www.sf.gov/join-or-rejoin-workforce
# 2024-10-22 14:59:08,102 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:08,107 - INFO - Content relevance: False
# 2024-10-22 14:59:08,325 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 404 Not Found"
# 2024-10-22 14:59:08,326 - ERROR - Error generating keywords: Error code: 404 - {'error': {'message': 'The model `o1-mini` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# 2024-10-22 14:59:09,284 - INFO - Crawling depth 3: https://www.sf.gov/learn-about-sf-fellowships
# 2024-10-22 14:59:11,891 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:11,896 - INFO - Content relevance: False
# 2024-10-22 14:59:12,120 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 404 Not Found"
# 2024-10-22 14:59:12,121 - ERROR - Error generating keywords: Error code: 404 - {'error': {'message': 'The model `o1-mini` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# 2024-10-22 14:59:12,696 - INFO - Crawling depth 3: https://www.sf.gov/news/topics/jobs
# 2024-10-22 14:59:15,077 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:15,092 - INFO - Content relevance: False
# 2024-10-22 14:59:15,323 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 404 Not Found"
# 2024-10-22 14:59:15,324 - ERROR - Error generating keywords: Error code: 404 - {'error': {'message': 'The model `o1-mini` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# 2024-10-22 14:59:16,566 - INFO - Crawling depth 2: https://www.sf.gov/apply-technologist-positions
# 2024-10-22 14:59:18,613 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:18,616 - INFO - Content relevance: True
# 2024-10-22 14:59:19,235 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:19,237 - INFO - Should follow https://www.sf.gov/apply-technologist-positions#mainContent: False
# 2024-10-22 14:59:19,933 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:19,938 - INFO - Should follow https://www.sf.gov/interest/: False
# 2024-10-22 14:59:20,596 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:20,601 - INFO - Should follow https://www.sf.gov/support: False
# 2024-10-22 14:59:21,331 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:21,354 - INFO - Should follow https://www.sf.gov/business-analysis: False
# 2024-10-22 14:59:22,365 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:22,371 - INFO - Should follow https://www.sf.gov/programming: False
# 2024-10-22 14:59:23,102 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:23,106 - INFO - Should follow https://www.sf.gov/engineering: False
# 2024-10-22 14:59:23,814 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:23,817 - INFO - Should follow https://www.sf.gov/role/?id=3743990005678916: False
# 2024-10-22 14:59:28,023 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:28,032 - INFO - Should follow https://www.sf.gov/role/?id=3743990005678046: False
# 2024-10-22 14:59:28,687 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:28,690 - INFO - Should follow https://www.sf.gov/role/?id=3743990005672946: False
# 2024-10-22 14:59:29,507 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:29,510 - INFO - Should follow https://www.sf.gov/role/?id=3743990005672126: False
# 2024-10-22 14:59:30,165 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:30,169 - INFO - Should follow https://www.sf.gov/role/?id=3743990005631426: False
# 2024-10-22 14:59:31,280 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:31,282 - INFO - Should follow https://www.sf.gov/role/?id=3743990005609226: False
# 2024-10-22 14:59:31,967 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:31,969 - INFO - Should follow https://www.sf.gov/role/?id=3743990005608936: False
# 2024-10-22 14:59:32,547 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:32,548 - INFO - Should follow https://www.sf.gov/role/?id=3743990005607526: False
# 2024-10-22 14:59:33,279 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:33,280 - INFO - Should follow https://www.sf.gov/role/?id=3743990005556596: False
# 2024-10-22 14:59:33,814 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:33,819 - INFO - Should follow https://www.sf.gov/role/?id=3743990005406607: False
# 2024-10-22 14:59:34,447 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:34,449 - INFO - Should follow https://www.sf.gov/role/?id=3743990005402776: False
# 2024-10-22 14:59:35,070 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:35,072 - INFO - Should follow https://www.sf.gov/role/?id=3743990005227866: False
# 2024-10-22 14:59:35,900 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:35,905 - INFO - Should follow https://www.sf.gov/role/?id=3743990005069906: False
# 2024-10-22 14:59:36,560 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:36,561 - INFO - Should follow https://www.sf.gov/role/?id=3743990002931996: False
# 2024-10-22 14:59:37,149 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 14:59:37,154 - INFO - Should follow https://www.sf.gov/role/?id=3743990002931986: False
# 2024-10-22 15:03:26,880 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 15:03:26,941 - INFO - Should follow https://www.sf.gov/apply-technologist-positions?offset=16: True
# 2024-10-22 15:03:27,752 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 15:03:27,758 - INFO - Should follow https://www.sf.gov/apply-technologist-positions?offset=16: False
# 2024-10-22 15:03:28,335 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 15:03:28,338 - INFO - Should follow https://www.sf.gov/knowledge/: True
# 2024-10-22 15:03:28,987 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 15:03:28,992 - INFO - Should follow https://www.sf.gov/knowledge/application-errors: False
# 2024-10-22 15:03:29,681 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 15:03:29,686 - INFO - Should follow https://www.sf.gov/accommodations/: False
# 2024-10-22 15:03:30,394 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 15:03:30,397 - INFO - Should follow https://www.sf.gov/interest/: False
# 2024-10-22 15:03:31,094 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 15:03:31,097 - INFO - Should follow https://www.sf.gov/assistance/: False
# 2024-10-22 15:03:32,340 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 15:03:32,343 - INFO - Should follow https://www.sf.gov/trust/: False
# 2024-10-22 15:03:32,596 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 404 Not Found"
# 2024-10-22 15:03:32,601 - ERROR - Error generating keywords: Error code: 404 - {'error': {'message': 'The model `o1-mini` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# 2024-10-22 15:03:33,937 - INFO - Crawling depth 3: https://www.sf.gov/knowledge/
# 2024-10-22 15:03:36,063 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-10-22 15:03:36,066 - INFO - Content relevance: False
# 2024-10-22 15:03:36,154 - INFO - Results saved to semantic_results_20241022_150336.json
# 2024-10-22 15:03:36,154 - INFO - Crawl completed successfully. Results saved to semantic_results_20241022_150336.json
# Crawl completed!

# %% [markdown]
# https://www.sf.gov/
#
# We're making a chatbot for the HR in San Francisco

# %%
from rufus import Rufus
